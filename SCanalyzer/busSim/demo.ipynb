# %%
x_num = 1000000
# y_num = 10
# grid = []

# %%
li2 = [[] for x in range(x_num)]

# %%
li = []
for x in range(x_num):
    li.append([])

# %%
class A:
    def __init__(self):
        self.id = 0
        self.count = 1
        self.id2 = int()
    
    def __repr__(self):
        return '{}, {}, {}'.format(self.id, self.count, self.id2)

# %%
li = [[1,2],[2,1],[3,9],[4,0]]
li.sort(key=lambda l:l[1])

# %%
for index, x in enumerate([1,2,3,4]):
    print(index,x)
# Out:
# 0 1
# 1 2
# 2 3
# 3 4

# %%
a2 = A()
a2
# Out:
# 0, 1, 0

# %%
if None:
    print('none')

# %%
a = None
if a.b and a:
    print('a')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_4736/3239355582.py in <module>
#       1 a = None
# ----> 2 if a.b and a:
#       3     print('a')
#
# AttributeError: 'NoneType' object has no attribute 'b'
